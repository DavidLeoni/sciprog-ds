# %%
import jupman
jupman.init()
# Out:
# <style>
#
#     #jupman-nav {
#         position: fixed;
#         top: 10px;
#         left: 5px;
#         background: white;
#         width: 200px;
#         padding: 10px;
#         z-index: 10;
#     }
#
#     /* style="background: rgba(255, 255, 255, 0);" class="unstyled" */
#
#     #jupman-toc {
#         position: fixed;
#         top: 100px;
#         left: -55px;
#         background: rgba(255, 255, 255, 0);
#
#         height: 80%;
#         width: 200px;
#         padding: 20px;
#         z-index: 10;
#         overflow-y: scroll;
#             /* font-size: 50%; */
#     }
#
#
#
#     code {
#         background-color:rgb(245, 249, 249) !important;
#     }
#
#
#     .jupman-nav-item {
#         font-weight:bold;
#         font-size:120%
#     }
#
#     .jupman-chapter-link {
#         font-size:150%;
#         margin-right:15px;
#     }
#
#     .jupman-chapter-link a {
#         text-decoration: none;
#     }
#
#     .jupman-title {
#         font-size:250%;
# ...

# %% [markdown]
# # Old news
#
# <div class="alert alert-warning">
#
# **Warning**: last news are published at the [top of course description](index.ipynb)
#
# </div>

# %% [markdown]
# **25 August 2020 - Published 2020-08-24 exam results**
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2020-08-24-public-grades.html)
# - [corrections](https://drive.google.com/drive/folders/1W8ij-9Th-Zt5qgEBXl-vrhIutDNihiAp?usp=sharing)
# - [solutions](exams/2020-08-24/exam-2020-08-24-solution.ipynb)
#
# 27 July 2020 - Published 2020-07-17 exam results
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2020-07-17-public-grades.html)
# - [corrections](https://drive.google.com/drive/folders/17K2s9rd_P3scJPkvODxwySyN5_Zv3gxU?usp=sharing)
# - [solutions](exams/2020-07-17/exam-2020-07-17-solution.ipynb)
#
# 17 June 2020 - Published 2020-06-16 exam results
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2020-06-16-public-grades.html)
# - [corrections](https://drive.google.com/open?id=13nLV7VqPYtyYpkPOkfOe2VLxxcSP0u1B)
# - [solutions](exams/2020-06-16/exam-2020-06-16-solution.ipynb)
#
# 4 March 2020 - Published 2020-02-10 exam results
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2020-02-10-public-grades.html)
# - [corrections](https://drive.google.com/open?id=1CBVHvf2gBrB7tCym2iDgTDIRPO8dSV-r)
# - [solutions](exams/2020-02-10/exam-2020-02-10-solution.ipynb)
#
#
# 31 January 2020 - Published 2020-01-23 exam results
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2020-01-23-public-grades.html)
# - [corrections](https://drive.google.com/open?id=1HdSp9Hs2autPGCV718HZfSZr9oiZ-NCU)
# - [solutions](exams/2020-01-23/exam-2020-01-23-solution.ipynb)
#
# 7 January 2020 Extra tutoring:
#
# (Beware rooms are not always the same)
#
# - Tue 14 January 10.00 - 12.00 A216
# - Wed 15 January 10.00 - 12.00 A216
# - Thu 16 January 10.00 - 12.00 A214
# - Fri 17 January 10.00 - 12.00 A221
# - Tue 21 January  10.00 - 12.00 A216
#
# 23 December 2019 - Published Midterm B grades:
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2019-12-20-public-grades.html)
# - [corrections](https://drive.google.com/drive/folders/1tUo9e-V3mzLVNipNXfBwFqh_Wv-WIcSp?usp=sharing)
# - [solutions](exams/2019-12-20/exam-2019-12-20.ipynb)
#
# 07 December 2019 - Set midterm Part B date:
#
# - Friday 20th December, lab A202, from 11.45 to 13.45
# - Admission: students who got grade >= 16 at the first midterm
#
# 06 December 2019: Published midterm results:
#
# - [detailed grades](http://davidleoni.it/etc/spex/exams/2019-11-07-public-grades.html)
# - [corrections](https://drive.google.com/open?id=1RBLG6h843RPFXn6JAeyZaMDHhKhX2eRs)
#
# 28 November 2019: Set exams dates:
#
# - 23 January  8:30-13:30 A201
# - 10 February 8:30-13:30 A202
#
# 7 November 2019: published [Midterm Part A solution](exams/2019-11-07/exam-2019-11-07-solution.ipynb)

# %% [markdown]
# 5 November 2019: WARNING: TUTORING CHANGE
#
# Since Fridays apparently aren't the best day for tutoring (nobody went twice in a row), we're moving Friday tutoring to Wednesday 9:00-11:00 starting with Wednesday 6 November. Rooms: A219 until Wednesday 13 November included, A218 afterwards
#
# Given the fact many of you took ages to do the midterm simulation, I'd recommend attendance.
#
# 2 November 2019:
#
# - published [Midterm simulation solutions](exams/2019-10-31/exam-2019-10-31-solution.ipynb)
# - added NaN and infinities section to [matrix: numpy exercises](matrices-numpy/matrices-numpy-solution.ipynb)
# - improved [pandas exercises](pandas/pandas-solution.ipynb)
# - added [functions exercises](functions/functions-solution.ipynb)
#
# 24 October 2019: updated [numpy matrices](matrices-numpy/matrices-numpy-solution.ipynb) and [visualization](visualization/visualization-solution.ipynb)
#
# 22 October 2019: WARNING: TUTORING TIMETABLE CHANGE!
#
# Unfortunately, due to reasons beyond our control we need need to change timetable for tutoring:
#
# - Mondays remain the same:   room A215 from 11.30-13.30
#
# - Fridays change:   instead of previous 12.30-14:30,   the new hours will be 11.00-13.00. Friday room is also changed, it will be A218 for all fridays
#
#
# - Graph formats draw functions:
#     - fixed bug about username not found in windows
#     - now it is possible to save to file in draw_mat, draw_nx, etc by passing filename in parameter `save_to`, [see documentation](https://sciprog.davidleoni.it/graph-formats/graph-formats-sol.html#Saving-a-graph-to-a-file)
#
# 17 October 2019 : rewrote [Graph formats](graph-formats/graph-formats-solution.ipynb) page
#
# 12 October 2019 : tutoring service has been set up on Mondays and Fridays starting Monday 14th October, see [timetable](#Tutoring)
#
#
# 10 October 2019: Save the dates:
#
# - MIDTERM PART A SIMULATION: 31 october 15:30-17:30 room a202
#
# - MIDTERM PART A: 7 november 11:30-13:30 room b106
#
# IMPORTANT: differently from past Part A exams, there will also be an exercise on Pandas.
#
# - merged Part A graph stuff into [graph formats](https://sciprog.davidleoni.it/graph-formats/graph-formats-sol.html)
#
# 7 October 2019
#
# - added [Tuples](tuples/tuples-solution.ipynb) page (were extracted from [Lists](lists/lists-solution.ipynb))
# - updated [Dictionaries](dictionaries/dictionaries-solution.ipynb)
# - rewrote [Sets](sets/sets-solution.ipynb), now belongs to Part A
#
# 3 October 2019: updated [Lists](lists/lists-solution.ipynb)
#
# 1 October 2019
#
# - updated [Strings](strings/strings-solution.ipynb)
# - updated  [error handling and testing](errors-and-testing/errors-and-testing-solution.ipynb)
#
# 24 September 2019
#
# - updated  [introduction](introduction/introduction-solution.ipynb)
# - added [Python basics](basics/basics-solution.ipynb)
#
# 27 August 2019: published  [exam solutions](exams/2019-08-26/exam-2019-08-26-solution.ipynb)
#
# 2 July 2019: published  [exam solutions](exams/2019-07-02/exam-2019-07-02-solution.ipynb)
#
# 10 June 2019: published  [exam solutions](exams/2019-06-10/exam-2019-06-10-solution.ipynb)
#
# - 13 January 2019: published  [exam solutions](exams/2019-02-13/exam-2019-02-13-solution.ipynb)
# - 23 January 2019: published [exam solutions](exams/2019-01-23/exam-2019-01-23-solution.ipynb)
# - 23 January 2019: removed children() method from GenericTree (you shouldn't use it anyway)
# - 10 January 2019: published [Part B midterm solutions](exams/2019-01-10/exam-2019-01-10.ipynb)
# - 9 January 2019: added topsort to [graph algorithm exercises](graph-algos/graph-algos.ipynb)
# - 24 December 2018:
#     * Added to [LinkedList exercises](linked-lists/linked-lists.ipynb): EqList, Cloning, and More exercises
#     * Added to [Sorting exercises](sorting/sorting.ipynb): chains, SwapArray exercises
#
# - 14 December 2018, published:
#     * [stack exercises](stacks/stacks.ipynb)
#     * [queues exercises](queues/queues.ipynb)
#     * [set exercises](sets/sets.ipynb)
#
# - 12 December 2018: the lab of Friday 14th Dec is moved to _A211_ from 8:30 to 11:30 . As you have noticed, there is even an extra FREE hour of coding, so don't miss this special Friday offer !
# - 11 December 2018: published [graph algorithm exercises](graph-algos/graph-algos.ipynb)
# - 9 December 2018: fixed [tree exercises](trees/trees.ipynb)
# - 6 December 2018: published [linked-lists exercises](linked-lists/linked-lists.ipynb)
# - 5 December 2018: expanded [sorting](sorting/sorting.ipynb) with insertion_sort, merge_sort, quick_sort
# - 16 November 2018: Published [midterm solutions](exams/2018-11-16/exam-2018-11-16-solution.ipynb)
# - 14 November 2018: Published [midterm simulation exam solutions](exams/2018-11-13/exam-2018-11-13-solution.ipynb)
#
# - 6 November 2018: RESTRUCTURED WEBSITE
#     - Added [Exam modalities](#What-I-expect) , please read them
#     - Added difficulty ratings to exercises
#     - Added sections:
#         - [Strings](strings/strings-solution.ipynb)
#         - [Graph formats](graph-formats/graph-formats-solution.ipynb)
#         - [Binary relations](binary-relations/binary-relations-solution.ipynb)
#         - [Pandas](pandas/pandas-solution.ipynb)
#     - Expanded sections:
#         - [Lists](lists/lists-solution.ipynb)
#         - [Visualization](visualization/visualization-solution.ipynb)
# - 26 October 2018: IMPORTANT: there will be NO LABS on Tuesday 20 October and on Friday 2 November. Next lab is scheduled for Tuesday 6 November.
# - 23 October 2018:
# Restructured Basic data structures material, separating into pages [Lists](lists/lists-solution.ipynb) and [Dictionaries](dictionaries/dictionaries-solution.ipynb)
# - 16 October 2018:
#     - restructured Matrix material, separating matrix chapter into pages [Matrix as lists of lists](matrix-lists/matrix-lists-solution.ipynb) and  [Matrix networks](matrix-networks/matrix-networks-solution.ipynb)
#     - fixed graph drawing function and moved it to `sciprog` module.
# - 13 October 2018: added explanations to [Matrix as lists of lists lesson](matrix-lists/matrix-lists-solution.ipynb)
# - The missed lab of 2nd October is moved to Wednesday 10 October 11.30-13.30 room A209 Povo 1. Other scheduled labs will be held regularly.
# - 5 October 2018 14:30 A214 Povo 1: lab to be held regularly
# - 2 October 2018: Lab 2 did not happen, I apologize for the inconvenience. See you on Friday 5th October at 14:30
# - 21 Sept 2018: Moved website from old [QCB master sciprolab2.readthedocs.io](https://sciprolab2.readthedocs.io) to [sciprog.davidleoni.it](https://sciprog.davidleoni.it)
