# %%
import sys
sys.path.append('../../')
sys.path.append('../../trees')

from sciprog import draw_gt
from gen_tree_test import gt

# TODO DELETE

t  = gt('a', 
            gt('b', 
                    gt('e',
                            gt('f'), 
                            gt('g', 
                                    gt('i')),
                    gt('h')),
            gt('c'),
            gt('d')),
            gt('m', 
                    gt('n',
                            gt('o'), 
                            gt('p', 
                                    gt('q')),
                    gt('r'))))

draw_gt(t, options={'graph':{ 'newrank':'True'}})
